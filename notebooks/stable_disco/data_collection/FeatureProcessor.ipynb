# %%
# %load_ext autoreload
# %autoreload 2
import os
import sys
sys.path.insert(0, os.path.abspath('..'))
sys.path.insert(0, os.path.abspath('../..'))

import importlib

import contextlib

import json
import os
import random

import numpy as np
import torch
import pandas_streaming
from collections import defaultdict
from fileutils import get_default_path


from automation.automationmanager import make_default_manager
from automation.crawler.midjourneycrawl import crawl_gallery_user, crawl_gallery_feed
from automation.midjourney.midjourneyutils import FeedType

from storage.data.image.remoteimageinfo import imgs_to_cmds
from storage.data.image.crawledimagegroups import CrawledImageGroups
from storage.data.command import Command
from storage.data.command.commandbuilder import CommandBuilder
from storage.data.user.userids import MJ_USER_TO_ID
from storage.data.user.mjuser import MJUser
import time
from util import Stopwatch
import datetime

import ai.stabledisco as sd
import ai.torchmodules as torchmodules
import ai.torchmodules.data as torchdata
import ai.torchmodules.utils as torchutils
import ai.stabledisco.utils as sdutils
import clip
import ai.nlp
import torch
import torch.nn as nn
import pandas as pd
from storage.data.command.stablediscoprompt import arg_prompt_split

# %%
df_path = get_default_path("large_datasets", "aug_prompts.feather")
if "prompt_dataframe" in dir():
    del prompt_dataframe
prompt_dataframe = pd.read_feather(df_path)

# %%
prompt_dataframe.to_feather(df_path)

# %%
for row in prompt_dataframe.itertuples():
    idx = row[0]
    if idx != 0 and idx % 250000 == 0:
        print(len(prompt_dataframe) - idx)
    if row.text_tokens is None:
        continue
    prompt_dataframe.at[idx, "text_tokens"] = prompt_dataframe.at[idx, "text_tokens"].astype(np.uint16)

# %%
device = torchutils.get_default_device()
vit14_clip_model, preprocessor = clip.load('ViT-L/14')

# %%
import torchvision.transforms as T
import PIL
img_to_tensor = T.ToTensor()
def imgs_to_tensor(imgs):
    if isinstance(imgs, PIL.Image.Image):
        return img_to_tensor(imgs).cuda()
    return torch.stack(tuple((img_to_tensor(img) for img in imgs))).cuda()
preprocess = T.Compose([
        T.Resize(vit14_clip_model.visual.input_resolution, interpolation=T.InterpolationMode.BICUBIC),
        T.CenterCrop(vit14_clip_model.visual.input_resolution),
        T.Normalize((0.48145466, 0.4578275, 0.40821073), (0.26862954, 0.26130258, 0.27577711)),
    ])

# %%
print(len(prompt_dataframe[prompt_dataframe["img_features"].isna()]))
print(len(prompt_dataframe[prompt_dataframe["img_features"].notna()]))

# %%
prompt_dataframe["partial_img_features"] = None

# %%
import contextlib
partial = False
if partial:
    col = "partial_img_features"
else:
    col = "img_features"

def save_features(data_frame, idx_paths, partial=False):
    if len(idx_paths) == 0:
        print("No paths")
        return
    
    with torch.no_grad():
        to_process = []
        img_to_size = defaultdict(list)
        for idx, img_path in idx_paths:
            try:
                img = sdutils.load_img(img_path)
            except:
                continue
                
            img_to_size[img.size].append((idx, img))

        written = 0
        for size, lst in img_to_size.items():
            idxs = [x[0] for x in lst]
            if partial:
                features = get_partial_features([x[1] for x in lst])
                col = "partial_img_features"
            else:
                features = get_img_features([x[1] for x in lst])
                col = "img_features"
            
            for idx, feature in zip(idxs, features):
                data_frame.at[idx, col] = feature    
            del features
            
            written += len(lst)
            
        del img_to_size
        return written
    
def get_img_features(imgs):
    img_tensors = imgs_to_tensor(imgs)
    del imgs

    preprocessed_tensors = preprocess(img_tensors)
    del img_tensors

    return vit14_clip_model.encode_image(preprocessed_tensors).cpu().numpy().tolist()

def get_partial_features(imgs):
    img_tensors = imgs_to_tensor(imgs).half()
    del imgs

    x = preprocess(img_tensors)
    del img_tensors
    
    x = vit14_clip_model.visual.conv1(x)  # shape = [*, width, grid, grid]
    x = x.reshape(x.shape[0], x.shape[1], -1)  # shape = [*, width, grid ** 2]
    x = x.permute(0, 2, 1)  # shape = [*, grid ** 2, width]
    x = torch.cat([vit14_clip_model.visual.class_embedding.to(x.dtype) + torch.zeros(x.shape[0], 1, x.shape[-1], dtype=x.dtype, device=x.device), x], dim=1)
    x = x + vit14_clip_model.visual.positional_embedding.to(x.dtype)
    x = vit14_clip_model.visual.ln_pre(x)

    x = x.permute(1, 0, 2)  # NLD -> LND
    x = vit14_clip_model.visual.transformer(x)
    x = x.permute(1, 0, 2)  # LND -> NLD

    return x.cpu().numpy().tolist()
    

imgs_paths_to_process = []
per_df_write = 1000
start = time.perf_counter()
written = 0
per_save = 20000
torchutils.torch_garbage_collect()
for row in prompt_dataframe.itertuples():
    idx = row[0]
    
    if (not partial and row.img_features is None) or (partial and row.partial_img_features is None):
        imgs_paths_to_process.append((idx, row.img_path))
        
    if len(imgs_paths_to_process) > 0 and len(imgs_paths_to_process) % per_df_write == 0:
        written += save_features(prompt_dataframe, imgs_paths_to_process)
        imgs_paths_to_process = []
        torchutils.torch_garbage_collect()
        
        if written >= per_save:
            print(f"Writting {written}")
            written = 0
            prompt_dataframe.to_feather(df_file_path)
        
        end = time.perf_counter()
        diff = end - start
        start = end
        
        per_entry = diff/per_df_write
        rem_rows = len(prompt_dataframe[prompt_dataframe[col].isna()])
        print(f"Time per entry {per_entry}. Rem time {per_entry*rem_rows/60} minutes for {rem_rows} rows")
        print(f"Completed rows {len(prompt_dataframe) - rem_rows}")
print("done")

# %%
print(len(prompt_dataframe))
prompt_dataframe.reset_index(drop=True, inplace=True)
prompt_dataframe.drop_duplicates(subset="prompt", ignore_index=True, inplace=True)
prompt_dataframe = prompt_dataframe.sample(frac=1).reset_index(drop=True)
len(prompt_dataframe)
# Out:
# 16798194
# 16793602

# %%
prompt_dataframe.to_feather(df_path)

# %%
print(len(prompt_dataframe))
# Out:
# 16793602

# %%
prompt_dataframe["cfg"] = pd.to_numeric(prompt_dataframe["cfg"], downcast="float")
prompt_dataframe["width"] = pd.to_numeric(prompt_dataframe["width"], downcast="integer")
prompt_dataframe["height"] = pd.to_numeric(prompt_dataframe["height"], downcast="integer")
prompt_dataframe["num_imgs"] = pd.to_numeric(prompt_dataframe["num_imgs"], downcast="integer")
prompt_dataframe["steps"] = pd.to_numeric(prompt_dataframe["steps"], downcast="integer")
prompt_dataframe["seed"] = pd.to_numeric(prompt_dataframe["seed"], downcast="integer")

# %%
prompt_dataframe["prompt"] = prompt_dataframe["prompt"].astype(str)
prompt_dataframe["sampler"] = prompt_dataframe["sampler"].astype(str)
prompt_dataframe["user"] = prompt_dataframe["user"].astype(str)

# %%
df_path = get_default_path("large_datasets", "aug_prompts.feather")
prompt_dataframe.to_feather(df_path)

# %%
list(prompt_dataframe.loc[:1000, "prompt"])
# Out:
# ['a drawing of beethoven',
#  'breathtaking detailed painting of a beautiful side portrait of zendaya in a white cat sitting with her hands, cloak, charming, dnd character art by artgerm and greg rutkowski and artgerm and liam brazier and victo ngai and tristan eaton',
#  'farm girl with goats and lambs   is this not just too adorable and so retro - love it',
#  'arreglos de mickey mouse | decoracion con globos de mickey mouse-3 ...',
#  "these greek salad hummus pita pizzas are the perfect summertime appetizer or main course meal. olive oil grilled pita topped with spicy hummus and fresh greek salad. you're going to love this!",
#  'william robinson leigh poster featuring the painting zuni pottery maker by william robinson leigh',
#  'interesting 60 containers home on dwts',
#  'easy wedding cake cupcakes cupcake elegance wedding cakes glass house mountains 13836',
#  'passing through the ethereal portal to the iris van herpen doom experience, majestic dream in the space ',
#  'image for tropical beach wallpaper hammock wallpapers for desktop',
#  'recapturing the romance of reading at livraria lello | a pair of boots ...',
#  'application tips for medical school- heart sculpture',
#  'groom and groomsmen running through autumn woods',
#  'a to go into making the performance received glowing praise. photo by gili dailes',
#  '/big fat ugly men! fighting alien marines ',
#  "william robinson 'green mountains' ('mountain' series, 2nd of five) 1992. oil on linen. private collection, brisbane.",
#  'pink and blue cake with sugar flowers',
#  'scary skull wallpapers',
#  'frederic edwin church, oil on canvas, concept art, sharp focus, aleksi briclot, alexander trufanov, mandy jurgens, art deco ariana grande wearing witches outfit holding a blank canvas with an aqua, a striped orange and pink flower dress',
#  'disney-springs-towncenter_marketstalls',
#  'ojo de dios. simple version - 4 point. butterfly world, an 18 inch, 12-sided…',
#  'a cyberpunk overpowered computer. overclocking, watercooling, custom computer, cyber, mat black metal, alienware, futuristic design, beautiful dramatic dark moody tones and lighting, ultra realistic details, cinematic atmosphere, studio lighting, shadows, dark background, dimmed lights, industrial architecture, octane render, realistic 3d, photorealistic rendering, 8k, 4k, computer setup, highly detailed, desktop computer, desk, table, ikea',
#  'kermit as a professokermit as a professokermit as a professokermit as a professor',
#  'young sick bacchus',
#  'varadero travel guide for iphone, ipad & applewatch',
#  'ozark anglers comprehensive fishing news and reports for for blue creek fishing report',
#  'a beautiful japanese woman, lacivious pose, very detailed face, high-quality face, detailed painting,, detailed painting, academic art',
#  'pebridal white ivory color women ball gown wedding dresses appliques lace up cap sleeves lady bridal gown',
#  'renaissance revival victorian glazed and carved walnut cabinet or bookcase',
#  'fluffy buttermilk pancakes stuffed with a combination of fried and scrambled egg, topped with tomato, green pepper, onion and maple bacon strips, drizzled with chipotle syrup + canada 150 inspired all-canadian red hot burger.',
#  'monkey head eyeglasses vector illustration with green and the rest of the apocalypse, elden ring, oil painting, epic fantasy art, in the style of ruan jia and brad kunkle detailed',
#  'rockwood single level home rendering',
#  'wild unstructured groom boutonniere with hypericum berries, blush rose & greenery',
#  'portrait of emma watson playing hermione granger. smiling. happy. cheerful. smiling. western. closeup. fantasy. intricate elegant. highly detailed. face by ilya nazarov boris vallejo and tom bagshaw.',
#  'whoville houses photos',
#  'lee daniels on dramatizing billie holidays battle with the us government i owed it to her legacy',
#  'the queen of hearts poster',
#  '20 attractive kindergarten classroom decoration ideas to make it look catchy talkdecor',
#  'hero jesus christ by rosvaleera on hero jesus christ by rosvaleera hero jesus christ by rosvaleera',
#  'minimalist boho style art by artgerm and greg hildebrandt highly detailed labeled, poster, clean render,',
#  'real estate photography - 7972 fisher island drive, 7972, fisher island, fl, 33109 -',
#  'teresa wright background',
#  'fantasy landscape, beauty intricate, elegant, sharp focus, extremely detailed closeup portrait backview, low angle, realistic shaded, unpleasant face, fine details. anime. realistic shaded perfect face, fine details. anime. realistic shaded perfect face, fine details, high quality, 4k, trending on artstation ',
#  'zachary_samantha_engagement_session_sneak_peeks_11.21.18-7',
#  'birthday cake designs barbie : 86 best images about barbie doll fondant cakes on ...',
#  'adoration des mages (giotto)',
#  '9. 1956 pontiacchieftain wagon 870 deluxe',
#  'all the characters from the animated version of dorothy maier and ray - tracing, 4 k',
#  'upper body elegant muscular rugged handsome wizard soldier with a violine, as a dinosaur on a pedal bike with armenia quindio',
#  'cupcake with candle clip art',
#  'victorian pinhole photography portrait of post apocalyptic alien planet, digital art - digital art by clint cearley, featured on deviantart, trending on artstation, hd, 8 k, sharp high detail, sharp, vibrant, no crop ',
#  'couples maternity portraits, colorado maternity photographer, colorado springs maternity photos, castle rock maternity portraits, fun pregnancy photos, couples pregnancy photographer, beautiful pregnancy portraits',
#  'mount fuji meets flowers: top 5 scenic spring & summer spots to see mount fuji in 2019!',
#  'photo: olivia reduto traveled to mar-a-lago with his wife took me 7 hours boat for sale in grande prairie, alta. when the day august 15th click here to open a pizza on fire in still water with mountain dew can, game controler and madden 25 game.',
#  "valentine's buttercream frosting and candied ginger pieces, it's super easy starbucks inspired iced coffee",
#  'portrait of beautiful young caucasian latino girl woman with dark brown eyes and short dark hair in blue jeans royalty free stock photography',
#  'image pond of the world of lawl rpg wiki for beautiful small ponds',
#  'green and recording studios - 033',
#  'uncommon brown leather jacket for men',
#  'jerome powell riding a car made of moss emerging from a pig trough. many such children would',
#  'massive giant 65-year-old giant gaia goddess shedding one emotionless tear as she sits in front of the eerie fog, by tomasz alen kopera and tim burton matte painting of keanu reeves in a snowy vista. thematic costume. fire-scar over one eye, crystal ball, 3d render, octane rendered character sheet for animated films made by a web developer',
#  'selected focused of hulk wearing mech helmet, trending on artstation, very detailed',
#  'chocolate dipped christmas cookies. perfect for your holiday party!',
#  'barack obama, born 1961 kehinde wiley (born 1977) oil on canvas, 2018 © 2018 kehinde wiley',
#  'realistic detailed photography scene from a polyester or nylon material and clear bubble helmet, floating inside a glass bottle on a scooter, summer, pop art comic book by mark ryden',
#  'graffiti of darth vader helmet, drip painting!!, artwork by shepard fairey!',
#  'christmas lighthouse - 1000pc jigsaw puzzle by sunsout  \t\t\t  \t\t\t\t\tnew',
#  '1977 cadillac coupe deville saffron metallic color saffron. cars review. best american auto & cars review',
#  'new dodge m37 power wagon pick-up 1/10 sg. - page 3 dsc_0749',
#  'a deep valley with blue and titanium white, quinacridone magenta, hard lighting, masterpiece ',
#  'oil painting of a lake in the style of beksinski, parts by michael whelan, rossetti bouguereau, detailed art, beautiful face in profile, cute and aesthetic and a yellow dress, smiling coy, painting by sargent and and frederic edwin, rendered in cinema4d, 8k 3d, cgsociety, zbrush, no background ',
#  'chocolate truffle cake images : order chocolate truffle cake online, buy and send ...',
#  'rustic burlap and paint vase: 20+ creative ways to repurpse tin cans | www.knickoftime.net',
#  'gallery image 24 - treehouse, accomodation, hotel, ještěd',
#  'harley davidson wallpaper hd custom motorcycles chopper motorcycle wallpaper harley davidson wallpaper',
#  'the avengers as muppets ',
#  'a chef arranges bakery products at truebell stand',
#  'gallery lemonade stand for hire all with large angel ...',
#  'mid wales  log cabin holidays in wales  log cabin holidays',
#  'pin on charlotte moss quintessence',
#  '133/365 go green or get off my planet!',
#  'prompt:  fragile looking face drawn by takato yamamoto, ceramic looking face, cyber parts, inspired by naruto and bandai namco, clean ink detailed line drawing, intricate detail drawing, manga 1990',
#  'holiday stacking toy (crochet) | fiber arts | pinterest',
#  'junkanoo band wedding parade',
#  'gluten free chocolate chip cookies - the moxie collection',
#  'bakery hearts from split pastry with sugar powder on wooden royalty-free stock photo',
#  'ebay kitchen cabinets how to build an outdoor timberleaf pika teardrop camper trailer - $11,750 usd',
#  'extrêmement best 25+ amuse bouche ideas ideas on pinterest | aperitif, kumquat  ng79',
#  'specialized business insurance - view of two employees working on heavy machinery in the factory',
#  'close up of pancakes on a breakfast board with fruit',
#  'chocolate chip pudding cookies life in the lofthouse for life in the lofthouse',
#  'the green lamp, private collection',
#  'millet, roasted carrot and onion.',
#  'playing',
#  'a tree disguised as loaves of bread and hams on the throne, i will still keep turning. vintage photograph. muted color. color bleed.',
#  'roman catholics priests & popes worship an idol of lord krishna wallpapers wallpaper cave 18 800x800',
#  'used-1966-ford-fairlane-500',
#  'large notebook oswald the owl natural white',
#  'colorful storage ideas with graded design to look awesome',
#  'shaw shaq redemption: the movishaw shaq redemption: the movishaw shaq redemption: the movishaw shaq redemption: the movie',
#  'triple chocolate banana cake + espresso-nutella drizzle | recipe via displacedhousewife',
#  'kawaii bittermelon demon by hikari shimoda and martine johanna, highly detailed, mysterious lighting, artstation, octane ',
#  'blossoming meadow',
#  'two paper peonies in orange and purple color schemmidnight marauders by mandy jurgens and j.m.w. turner, artstation, 4k, black and white, 30mm',
#  'a realistic anime style aphian anime style',
#  'o838 imitation pearl bridal metal hair comb new arrived pretty crystal headpieces with alloy flowers',
#  'sunflowers and dry cracked ground, night sky, well lit fashion portrait by studio ghibli, pixar and hayao miyazaki, indsutrial steampunk',
#  'pin on art: thick oils & pastel landscape paintings by',
#  'petition to bring shell love bug home',
#  'aroma, aroma candle, aromatherapy, candle, lamp, spa icon',
#  "fazoli's offers value and variety with new 5 under $5",
#  "research shows some food additives may harm children's health",
#  'terraced landscape patio sloping landscaping sloped ... on small sloped backyard ideas on a budget id=24359',
#  'edinburgh featuring heritage architecture and night scenes',
#  'tommy hilfiger and dee ocleppo .jpg',
#  'steve waugh played 46 tests against england.',
#  'pauly shore: eyewitness to comedy history',
#  'dessert by katie grant photography - 002',
#  'delicious slice of pecan cheese cake stock photography',
#  'bird surreal painting by kevin sloan',
#  'bible last supper coloring pages',
#  '"photo of natural  by <a href=""/members/profile/mo.mariel"">mo.mariel</a> <br/>lentil-stew with rice, salad and home-made bread   <br/> march 12, 2015  - <a href=\'/contact/abuse/image/30209/95556\'>report</a>"',
#  'ariel cake decorations ariel cupcakes how to make by cakes stepbystep youtube',
#  'final fantasy concept art. cel shading. attractive face. thick lines. ',
#  'the jojo brothers from nintendo, oil on canvas, hd, by edmund blair leighton and katsuhiro otomo and geof darrow and phil hale and kent williams, dennis hopper, wayne barlowe machiej kuciara, dramatic lighting, alien hellscape, ultra detailed, digital painting, artstation, concept art, neons, interior',
#  'a beautiful elven ranger sitting down, happy face, long red pattern coat travel apparel, various poses on white background ',
#  'hand made christmas wreath with purple flowers',
#  'number cupcake cakes! great, simple idea. this one w flowers but can embellish w any theme.',
#  'luxury embroidery blue lace 100s egyptian cotton bedding sets queen rh ca dhgate com',
#  "women/'s slide on ...",
#  'butterfly lunch box for kids',
#  'download happy little girl fun with autumn leaves stock image - image of sweet, fall: 27436065',
#  'kerbal space program propaganda poster portrait of a tall clear square serving dish',
#  'snow tubing hill at seven oaks recreation in iowa',
#  'tipi spielzelt zelt f r kinder ohne kissen hangedeko und tipidecke. black bedroom furniture sets. home design ideas',
#  'house with 2 bedrooms in ponferrada, with wonderful mountain view, enclosed garden and wifi',
#  'canning vegetables: all you need to know',
#  'symmetrical features, ominous, magical realism, texture, intricate, ornate, royally decorated, body format, windows, many doors, roofs, complete house, whirling smoke, embers, red adornements, red torn fabric, radiant colors, fantasy, trending on artstation, volumetric lighting, micro details, 3 d sculpture, ray tracing, 8 k',
#  'fruit and salad bowls collection paid affiliate paid salad bowls collection fruit salad bowl ideas healthy food logo salad bowls',
#  "courtesy: hallie ford museum - 'along the waterfront' (1940)",
#  '12 inch christmas wreath',
#  'yellow-cake-favour.jpg',
#  'owls for your keys...these are too cute and would be inexpensive gift ideas!',
#  'portrait of kiernan shipka as sabrina spellman, white hair, intricate, elegant, glowing lights, highly detailed, digital painting, artstation, concept art, smooth, sharp focus, illustration, art by wlop, mars ravelo and greg rutkowski',
#  'birthday cake cookies how to plan a bash',
#  'toddler girls dress baby carnival dress up your small kitchen. i like how this bmi calculator could help lower blood pressure - photo #6. what does the mantle of the year-cladding complete, roof on pinterest toy story style, 4 k, glossy sphere, psychodelic colors, black background, unlock your inner guidance is real camp fire and ice grey eyes, portrait, photo realistic, ultra detailed ',
#  'cherry allover printed dress',
#  'a huge crowded megacity in the style of bloodborne, dark souls, demon souls, gothic art, dark fantasy, concept art, digital painting, volumetric lighting, trending on art station, evening time, warm sun light, god rays, highly detailed',
#  'local commercial kitchen space available 20 hr  catering',
#  'old barn, cataloochee valley, n. c. wyeth, sargent, oil on canvas, cinematic lighting, award winning, photo print.',
#  'a smartphone while sitting at a small stream of water, on dark gray food truck at the lebron james taking a sexy male blue dragon scale, digital art, ue 5, ',
#  'sunrise over a burnished wood table adn chairs, blue carpet and heavy net gown with ...',
#  'coping with the loss of a loved one during the holidays',
#  'lady dawson print by sir joshua reynolds',
#  'wedding refreshment bar',
#  'mature adult duvet cover featuring the photograph portrait of mature woman holding pie by george marks',
#  'amitai (back row, fourth from right) with the moving mountains for multiple myeloma team during a practice hike and climb in colorado.',
#  'a cute plush doll of a girl with green fire hair',
#  '"harvest cotton fabric 43""-orange pumpkins"',
#  "i'm all set up for a georgia jams pop up here at patagonia in atlanta, ga. y'all drop by and see me and taste the best low-sugar fruit spreads you've ever had. . . . #georgiajams #fruitspreads #eatwiththeseasons #popupatl #gettingintothatmarketseason #buylocal",
#  'pink, white, and orange flowers and greenery accent a tall shelf of antique jars',
#  'boy boxer holding championship belt in boxing. little champion.the big wins. stock photography',
#  'the mountains , canada',
#  'the groomsmen wore khaki pants with white shirts. the best man wore a yellow tie and the groomsmen wore green ties to match the bridesmaid dresses. they all completed the look with a sunflower boutonniere.',
#  'photography of 9 / 1 1, fantasy, intricate, elegant, highly detailed, digital painting, artstation, concept art, matte, sharp focus, illustration, hearthstone, art by artgerm and greg rutkowski and alphonse mucha',
#  'snibbens camping/cottages',
#  'pumpkin patch fun: vince woods\xa0farm',
#  '40 creative mittens and gloves gloves, mittens',
#  "lots of restaurants are closed on mondays, but that's not necessarily a bad thing.",
#  'used 1963 ford fairlane 500 2dr hardtop',
#  '1000 images about garage ideas on 9525',
#  'easter-bunny-5920976__480',
#  'bridal updo with small white flower accessories',
#  'reviews about the milford track, and new zealand more broadly',
#  'little girl on a beach ed hicks',
#  'vector baby dinosaurs seamless pattern, kids background free vector',
#  'how to cook quinoa in the rice cooker - project meal plan - rice cooker recipes chicken',
#  'omar sy as ancient libu girl, marvel comics, dark, intricate, highly detailed, by sam spratt, ',
#  'low - poly glowing holographic dinosaurs, fantasy, digital art, soft lighting, medium close up, highly detailed, 4 k ',
#  'dave dvorak/ddvorak@dailyherald.comfrom left, sam frye, 5, and sister isabel, 7, both of arlington heights dance to music at the arlington heights irish fest saturday, july 27.',
#  'evening shadows, backwater of the semi-naked cake from bethel bakery at the market. photo by hideaway report editor',
#  'heres the training plan that got tarzan star completely ripped the legend of tarzan1',
#  'chocolatebirthdaycakecookies2',
#  'cooper t1 austin special - chassis: c1   - 2016 goodwood revival',
#  'cat oil painting in front of swimming pool',
#  'kids and clock',
#  'hand made kodama night light terrarium',
#  'lake oeschinen, switzerland is a splendid unesco nature site, part of unesco world heritage sites in europe. discover more amazing heritage sites in europe from this article. #unesco #unescosites #unescositeseurope #europeunesco #switzerlandunesco #switzerland',
#  'dr.manhattan character from arcane, stylized, cinematic, ambient lighting, art by jc leyendecker gustav klimt artgerm greg rutkowski and magali villeneuve, highly detailed, digital illustration, smooth, sharp focus, illustration, morandi color scheme, intricate detailed painting, detailed eyes!!, final fantasy octopath traveler lovecraft ghibly',
#  'how to start a small flea market business',
#  'buffalo turkey panini with apples and blue cheese',
#  'san francisco pride parade 2015 (6641)',
#  'empire 19th century empire bookcase ~ vitrine for sale - image 3 of 12',
#  'breakfast buffet at cheval blanc randelhi',
#  'portrait of a realistic fantasy d & d, fantasy, greg rutkowski, artgerm, mucha, loish, wlop : : 2d matte dark gouache illustration : : ornate pictograph design of a woman with flowing red cape and cowl, silver and soft manga rose borders, artstation, concept art by john harris ',
#  'chikki brownie recipe',
#  'zumba instructor rene scavio, center, leads a zumbathon fundraiser in honor of deanna rivers and chris stewart on saturday, feb. 2, 2013, at orenda elementary school in clifton park, n.y. proceeds from ticket sales, raffles , baked goods and vendor sales will benefit the scholarship funds of these shenendehowa athletes who died in a car crash. (cindy schultz / times union) photo: cindy schultz / 10021020a',
#  'rhododendron_2',
#  '1 9 8 0 s film still of tom cruise on american pshyco movie, intense friendliness, with nothing behind the eyes, moody, nostalgic ',
#  'garage roof styles for garage roof styles',
#  'top down view of a bed of marjoram.',
#  '20 charming vintage christmas decorations - ceramic christmas decorations',
#  'buy fine art painting joseph mary and child jesus. by artist unknown artist',
#  "chevrolet bel air nomad    - 2006 concours d'elegance paleis 't loo",
#  'stained glass lamp shades light woodland minstrels lampshade greentooth image collections',
#  'alien bird, fog scene, brutal architecture, straight edged buildings, street signs, traffic lights, rain, thunder, dystopian',
#  'healthy proteins and vegetables',
#  'pulcinella as mr olympia, mural by blu gemeos, street art of skinner, chris cunningham, art by pete mohrbacher and craig mullins and greg rutkowski and magali villeneuve, artgerm, jeremy lipkin and giuseppe dangelico pino and michael garmash, donato giancola ',
#  'log cabin in woods, costa rica with kids',
#  'summer strawberry lemonade 6',
#  'a homemade plane in the foreground mirrored the clouds in the background, one tree, dramatic lighting, jessica rossier, art station ',
#  'twin-engined vincent black shadow  http://www.redbubble.com/people/howyadoin/calendars/13088352-bikes #motorcycle #motorcycleart #vincentblackshadow',
#  'wonder : foto jacob tremblay, owen wilson',
#  'flamingo dinner party moscow mule',
#  'jimmy cricket with fellow comedian dusty young and fr david lupton',
#  '2013 winter riding thread-sea-ice-2.jpg',
#  'masterpiece chinese qing porcelain bowl daoguang mark & - 2',
#  "phil sheridan, assistant regional director of communications for the national park service, crosses a bridge over the great falls, monday, nov. 7, 2011, in paterson, n.j. the landmark became the nation's newest national historic park monday. the 77-foot waterfall, located in downtown paterson, is the second largest on the east coast and one of the largest in the nation. the falls once provided power to run factories that produced silk, locomotives and firearms and helped launch the american industrial revolution. (ap photo/julio cortez) photo: julio cortez / ap",
#  'glass sculpture of person infected with the mind, full of cannabis leaf, potent spell potion shop, water, fire, air, and fairy lights',
#  'a beautiful lace design with style like cult horror, maximum detail, sharp high detail, digital painting, trending on markets',
#  'slices of red artificial flowers and bird, oil on canvas',
#  'lock cargo shorts - raiment nyc',
#  '"james costello on twitter: ""#seapoint #sunset/#moon/#sea/#pools/#beach/#venus and #waves....you\'re welcome!  #travel https://t.co/ghdpr8imli"',
#  'used 2009 bentley brooklands  | greenwich, ct',
#  "this looks exactly like what a man would wear if he suddenly turned into a woman and didn't have his lesbian best friend around to dress him up. that said, it's terrible, but very old-doctor style. #doctorwho #whovians #wardrobemalfunction",
#  "award-winning journalist michael mosley (above) leads the team on the show, trust me i'm a doctor, which examines health claims such as the benefits of coconut oil.",
#  '"rogue valley peace choir at ""one voice,"" february 2018"',
#  'dine alfresco on the aft deck',
#  'taylor swift as a dog ',
#  'anime 2339x1654 anime digital digital art artwork landscape sky anime sky animals architecture modern building water train train station clouds skyscape nature plants grass apocalyptic ruin ruins sun sun rays colorful drawing digital painting sign urban fantasy art outdoors duck old building',
#  'straight path, mystical symbols of death judging in esoteric architecture building spaceport by mark maggiori, trending on artstation, by a lake drawn by charles vess and jean delville, detailed, intricate ',
#  'one of the empire state building, ny, 2010',
#  'modern grey designer suit  for the groom with red bow tie',
#  '"stephen ""ragga"" marley performs ""the fruit of life summer tour"" at brooklyn bowl las vegas"',
#  'news-times photo: wade evanson - first year varsity football coach cole linehan provides encouragement to a couple local kids during the little guy youth camp in banks.',
#  'photo french macarons coffee lilac flowers cup food branches still-life  for mobile phone macaron flower syringa',
#  'small cyberpunk jellyfish, cables everywhere, blue tones, dawn volumetric lighting',
#  'fairytale wedding disney michelle roller photography cambria pines lodge',
#  'london, pastel colors, ornate, digital painting, smooth, sharp focus, moebius, victo ngai, artgerm, willem claesz heda and j. c. leyendecker, hd ',
#  "a sotheby's assistant shows the 50.05 carat heart-shaped d-colour internally flawless diamond pendant which will be on display at the moon, a detailed metallic temple on a wooden board with lanterns at night, by greg rutkowski, dariusz zawadzki, carlos schwabe, tyler edlin, gonzalo fuenmayor, ivan shishkin",
#  '. catholic priest fabio colindres (l) speaks with a member of mara salvatrucha gang during a mass at the prison of ciudad barrios, 160 km east of san salvador, el salvador on june 19, 2012. inmates participated in a mass to celebrate 100 days after a truce was declared between gangs and the salvadorean goverment.  afp photo/ jose cabezas/afp/getty images',
#  'colorful illustration by mandy jurgens ',
#  'how to make a lotus flower out of paper',
#  'colourful-christmas-table-setting-8a-pretty-life',
#  '1958 topps mickey mantle all star baseball cards',
#  "image: a new study indicates more people suffering from alzheimer's disease are dying at home (photo courtesy of canstockphoto).",
#  '2006 flstfi fat boy',
#  'fingerfood catering',
#  "mf doom real mc's, hip hop album cover art, portrait illustration, concept illustration, album cover art, pop art, art by ashley wood, alphonse mucha, laurie greasley and josan gonzalez. cinematic. dynamic lighting. realistic proportions. creative design. concept art. cell shading. ",
#  '8k, beautiful, high quality, 1 6 k',
#  "secret garden jigsaw puzzle 500/1000/2000 children's educational toys woodcraft assembly kit handmade assembled chinese ancient costume suit for rental on a throne of monaco displays at this just town pin chrysler today van and jesper ejsing and by feng zhu and loish and rossdraws",
#  'evau0027s historical costuming blog a womanu0027s gown from lyon 1565  sc 1 st  pinterest & evau0027s historical costuming blog: a womanu0027s gown from lyon 1565 ...',
#  'exquisite newly built 16 000 square foot apartment.',
#  'traditional custom exhibition stand for neudorff',
#  'summer girl wedding princess clothing kids lace ceremonies party pageant dress for girl, retro doll and grogu, baby yoda plushies',
#  "to match the scale of the vaulted ceiling in the owners' bedroom, sroka specified a pencil-post bed from hickory chair.",
#  'soft blurred bokeh fuzzy police light night texture over black background ',
#  'photo of gallery: sega amusements at iaapa 2015, orlando',
#  'hour of a beautiful dark elf witch with long curly hair under black hole there lived an isolated structure in the center, symmetrical shot, idiosyncratic, relentlessly detailed, pastel, limited colour palette, cinematic colors, made by stanly artgerm lau, greg rutkowski, ilya kuvshinov, inspired by detailed graphic novel by fiona',
#  'lakeside with spectacular view | okanagan gallery',
#  'agent carter season 2 character portraits feature wynn everett as madame masque',
#  'oil painting, high detail, warm lighting,',
#  "intro23 if you remember at least 10 of these 14 sweets then you're a true 80s child!",
#  'stacked red velvet pancakes topped with pomegranate seeds',
#  'sunset with wax palms, the national tree of colombia and with up to 60 meters height the tallest palm on earth',
#  'grand solmar lands end resort and spa- all inclusive optional',
#  'brain gyri pattern on its face. 4k symmetrical portrait, character turnaround, trending on artstation, luminous',
#  'baby on wooden horse. illustration of a cute baby on wooden horse royalty free illustration',
#  'cordan apartment with a tomato, looks like an indoor christmas decorations to horrify and make these cookies are a guiltless treat with the stars',
#  "classic lemon meringue pie recipe with lots of tips and tricks for a perfect pie every time! no more weeping and shrinking.\xa0this's the best! #lemonmeringuepie",
#  'vintage hummel figurine - gift from a friend',
#  'spring flowers porch decor with a basket sign by sadie seasongoods, featured on funky junk interiors',
#  'exotic garden, paris   nestled at the bottom of a small parisian impasse is now an urban garden of 35 sq. meter with an exotic atmosphere. a particular attention to detail is provided to create intimacy and lush.',
#  'vietnam wedding photographer 17',
#  'guess how many candy corn',
#  'sew n go tote quilted handbag - pdf pattern by jo-lydias attic designs  + how to add rickrack to seams free video tutorial',
#  'a slice of oreo cake is on its side and a piece of it is on a fork, showing the frosting. there are cookies stacked in the background.',
#  'christmas wreath cupcakes by pastry chef elise strachan - recipe',
#  'file white mercedes benz g 63 amg 6x6 fr london14 jpg wikimedia commons',
#  'flour girl designs non traditional wedding cakes awesome',
#  'the best ski resorts and hotels in north america readers choice photos condé nast traveler',
#  'grey porsche careers 4s red top up by co',
#  "a regular intake of green tea can help to keep the prostate healthy. it's best to brew it for five minutes",
#  ', matte painting, by frank frazetta scarlett johansson in dark souls in high altitude, lighting, clouds, artgerm, realistic, vivid,',
#  "berwick men's waterproof coat by alan paine",
#  'fuso canter 7c15 21ft dropside manual=4t payload ! - image 2',
#  'several dv multi-sport athletes only focusing on football',
#  'miranda (sorcha breen) watches the ship foundering in the swirling tempest.',
#  'cap toe oxfords - tan - the dapper man',
#  'easter and spring icons',
#  'ohfune-hoko appeared in the yama-hoko junko cruise of the kyoto gion-matsuri festival',
#  "3 / 4 fine french art deco flowers, frank lloyd wright, by gaudi, bokeh, long exposure, film grain, dye transfer colour photograph artistic polaroid of clementine oranges with a bright cafe, 3 d render by android jones and j'den ceya mccrea work in small-town west texas food bank's general manager, paul carmichael at art.com",
#  'musee mecanique barber shop',
#  'downton abbey inspired recipes with cheese',
#  'high roller linq | 7 night itinerary for north lake tahoe for your',
#  'cute fluffy ferret in the black witch hat flying vector sombrero de bruja',
#  'a screenshot of mariano goya - spanish blackboard academy',
#  'wedding chair decoration ideas for ceremony',
#  'hyper detailed kawaii liquid singer portrait seen transforming into the strangling network of dystopian gilded and aerogel and milky fruit and her delicate hands hold of gossamer polyp blossoms bring iridescent fungal flowers whose spores black the foolish stars by jacek yerka, mariusz lewandowski, hopper and james gilleard, beksinski, ryden, wolfgang lettl, hints of yayoi kasuma, octane render, 8 k',
#  'elaborate stained glass depiction of an anime girl after rain, brush strokes, watercolor trending on artstation, cgsociety cg awards, rtx on, high detail, environment, sharp focus',
#  'banana waffles with spiced rum pecan syrup',
#  'young woman contemplating two embracing children by william-adolphe bouguereau',
#  'mg midget dimensions',
#  'a review of the luton hoo hotel',
#  "my family's must-haves. we order it for his wedding day following teeth whitening is the perfect drink to beat the summer ocean beach hout bay - devon - stock image",
#  'colorado, needle mountains, san juan del guia beach at ilima terrace.',
#  'beautiful white ball gowns princess kids wedding dresses 2018 lace ...',
#  'a 120m-long model of the dead halloween sugar cookies with a zesty lemon dressing. super fresh, sweet yet tart creamy lemon filling.',
#  '35+ charming french blue beautiful flowers 6 inches',
#  'high school boy and girl doing homework in the 50s',
#  'carrots sit dolloped on a plate with kiwi and sausage',
#  'day of the dead sugar skull shirt | unisex t-shirt',
#  'free bear valentines heart coloring pages di 2020',
#  "closeup photo of cheesy dip with crackers. new year's eve appetizers and drinks recipe roundup.",
#  'a filipina woman wearing destiny hunter armor, wearing a hooded cloak, beautiful face!!!!, brown skin, blue eyes, brown hair in a bob, 2 7 years old, cg animation, realistic, character select portrait, by artgerm, greg rutkowski, alphonse mucha, 3 d ',
#  'close up of chicken jalfrezi and white rice',
#  'profile photo of a smiling hiker in a field of royalty free stock photo',
#  'barbershop - jacob grossman family first haircuts and shaves',
#  'file - in this aug. 30, 2015, file photo, bruno mars, left, and mark ronson accept the award for male video of the year for ¿uptown funk¿ at the mtv video mu...',
#  'the flathead river of montana in autumn',
#  'hong kong in a fun weeknight dinner but don ...',
#  'thanksgiving desserts pictures  splurge worthy thanksgiving dessert recipes southern living',
#  'peony - flower girl dress. party dress pdf pattern tutorial, easy sew, sizes 12m-10 included',
#  'two frogs by julian calle, wlop, denis villeneuve, lubezki, gaspar noe',
#  'photo of 10 fall garden decorating ideas, amazing and also attractive',
#  'a photorealistic picture of an evil man with a mask resembling jason voorhees using his own axe to kill a pig in the slaughterhouse ',
#  'king salmon airbrushed on a raft, realistic, stylized, artstation, brown skin, beautiful asian mix of dove cameron and kate beckinsale, dark wizard, lord of the mercedes benzshe got a backpack stands outside a burning city',
#  "new movie with alex jones and ron desantis playing the roles of the lead characters in the 1 9 9 4 movie dumb and dumber. promotional movie poster the size of a skyscraper hanging in new york's times square ",
#  'claire pettibone spring summer 2014 wedding dress primrose',
#  "ana de armas, stranger things steins gate locke & key pan's labyrinth, detailed realistic cinematic fashion character, pre-raphaelite boudoir portrait, lisa yuskavage christian schloe charlie bowater autumn skye paul lewin jeremy mann tom bagshaw j.c. leyendecker alyssa monks mandy jurgens david lazar caroline mackintos andrew loomis lauren nova chuck close ciryl rolando roby dwi ruan jia, hi-fructose, artstation, artgerm, wlop, 8k, soft lighting, rendered in octane, pnana de armas, stranger things steins gate locke & key pan's labyrinth, detailed realistic cinematic fashion character, pre-raphaelite boudoir portrait, lisa yuskavage christian schloe charlie bowater autumn skye paul lewin jeremy mann tom bagshaw j.c. leyendecker alyssa monks mandy jurgens david lazar caroline mackintos andrew loomis lauren nova chuck close ciryl rolando roby dwi ruan jia, hi-fructose, artstation, artgerm, wlop, 8k, soft lighting, rendered in octane, pnana de armas, stranger things steins gate locke & key pan's labyrinth, detailed realistic cinematic fashion character, pre-raphaelite boudoir portrait, lisa yuskavage christian schloe charlie bowater autumn skye paul lewin jeremy mann tom bagshaw j.c. leyendecker alyssa monks mandy jurgens david lazar caroline mackintos andrew loomis lauren nova chuck close ciryl rolando roby dwi ruan jia, hi-fructose, artstation, artgerm, wlop, 8k, soft lighting, rendered in octane, pnana de armas, stranger things steins gate locke & key pan's labyrinth, detailed realistic cinematic fashion character, pre-raphaelite boudoir portrait, lisa yuskavage christian schloe charlie bowater autumn skye paul lewin jeremy mann tom bagshaw j.c. leyendecker alyssa monks mandy jurgens david lazar caroline mackintos andrew loomis lauren nova chuck close ciryl rolando roby dwi ruan jia, hi-fructose, artstation, artgerm, wlop, 8k, soft lighting, rendered in octane, png",
#  "a woman's face in profile, made of dried flowers, in the style of rembrandt and gregory crewdson, dark and moody",
#  'low carb monte cristo sandwich with waffle bread recipe',
#  'a 22-story tall portrait of leonard cohen on the side of a stainless bowl filled with a large galloping horse destroying it.',
#  'screenshot of a giant chair in minecraft, 4k',
#  'lois griffin from family guy, hyperrealistic photo, realism, portrait, studio lighting',
#  'a huge dog as a beautiful dark medium wavy hair man from back',
#  'stay in an elegant, wood-built guesthouse overlooking the ocean',
#  'darth vader fighting luke skywalker in dark fantasy science fiction theme with lightning. wide detailed digital art, trending on artstation concept art trending on artstation pixiv skeb deviantart realistic hd 8 x 8 inches',
#  'a night light, reading a book next to colin kaepernick on the christmas carol written by charles camoin ',
#  'love is all you need hamper',
#  'hand painted european style oil canvas painting realist forest house landscape oil painting wall art picture painting  for room',
#  'mint green coral wedding headband hairband by jewelsalem on etsy, $38.00',
#  'german table centrepiece wild foliage arrangement orange pexels brown vase c 1904 odilon redon',
#  'the stunning cooloola coast, where it appears idiots tried hard to ruin it for everyone at the weekend.',
#  'thyme roasted chicken with herbed potatoes and roasted asparagus.  simple tasty and stylish roast dinner',
#  '1984, george orwell, ',
#  'laura ashley kitchen wallpaper: #lauraashleyss14. this wallpaper is floral & duck egg blue',
#  'easy summer tablescape coastal dining room',
#  'local apple pressing service can help cut down food waste',
#  'catering food buffet fotolia_29655918_subscription_monthly_xl',
#  'carmens designs blush flower girl dress with floral lace applique bodice and tulle high low bottom',
#  '1967 mgb v8 roadster,heritage shell, ultimate spec. for sale (picture 5 of 6)',
#  'orthodox christian icon coloring book featuring icons feast days and saints great resource for ke orthodox christian icons saint coloring catholic coloring',
#  'vfx movie old ships firing canons 8 5 mm f / 3 2. noise film photo - 11',
#  'bluejay flying above a large mushroom, with door and windows on the beach, pretty, hyper realistic, photography, 16k, white smoke, smoke with turquoise hair with green eyes',
#  'dark scifi, painted by zdzisław beksinski, cinematic, atmospheric, wide angle low cinematic lighting',
#  'gingerbread sugar scrub in a glass jar with a red bow and a gingerbread man on the label',
#  'a yellow orange 1983 zastava 750 vintage car',
#  'property for sale at 2050 s. highway a1a unit: 2, jupiter,  florida 33477',
#  'artwork by kilian eng and dan mumford and toshi yoshida and franklin booth showing a futuristic powerstation!! in front of a ( ( exploding volcano ) ), vintage scifi, high details, dramatic lightning,, 8 k',
#  '3d banana backpack cute canvas fold shoulder bags drawstring bag for 2-8 years old kids',
#  'portrait digital art - girl from the sun by willow schafer',
#  'yelawolf-press-pic-1',
#  'womens burberry knit sweatshirt red | small',
#  'stay in the marlborough sounds',
#  'gaufre_liegeoise',
#  'ball gown wedding dresses | paloma blanca',
#  "singer susan boyle performs on nbc's 'today' at rockefeller center on november 23 2010 in new york city",
#  'lush forest, highly detailed',
#  'bride smiles at groom during rainy fall engagement session in charlevoix, michigan.',
#  'all the best fruit drops individually wrapped 500g',
#  "music column: my morning jacket's resurgence with jim james at the head",
#  '"""metalsport wheels\' new 32"""" designs were the talk of the 2014 v-twin expo"""',
#  'girl watching moses - glorious empires-historical miniatures',
#  'along 231 24 x 36 oil on canvas  sold',
#  'penguin goddess, vivid colors, dark background, ultra detailed of a young cyborg woman, cyberpunk concept art of a disneyland carousel horse',
#  'the romanian bears are chasing skiers again',
#  'pink-swan-party-swan-baby-shower-inspiration',
#  'black man with cornrows and a purple rgb lighten gaming pc sitting on a white background. the concept of wanting to transfer shares to your children',
#  'colorful cars wallpapers top speed. black bedroom furniture sets. home design ideas santa fesouthwest style spanish within 10 outdoor garden design meaningful spaces hh design',
#  'white hair in a pretty brunette woman, short pink hair with a wolf, cyborg wolf by greg rutkowski and wayne barlowe ',
#  'roasted chicken with ready rice',
#  'classic world imports in charlotte north carolina fashion and costume by baby yoda being drunk by a garden. | photo by brady young',
#  '"""group of cyclists cycle over a bridge on the cycle path """"old treungenbanen"""""""',
#  'horses with float wagon',
#  'walking through the snowy forest near diamond lake, oregon',
#  'sunset on loch earn',
#  'under autumn - presque isle (porcupine mountains state park - upper michigan)',
#  'hms resolute painting - hms resolute in search of sir john franklin by francois musin',
#  'minimalistic beautiful landscape painting of architecture city abandoned unfinished building by rosa bonheur, edward hopper. beeple colors.',
#  'carnitas, eggs, rice and beans',
#  'extreme uhdr photorealistic photograp of your heart is ripping ',
#  "heart shaped chocolate flan with nutella valentine's dessert",
#  'off along the canal.',
#  "7commercial photography of the knights templar filter activated carbon face mask - it's okay to be reserved for special occasions.",
#  'production photograph - carousel - norman bowman, harriet shore - photographer catherine ashmore - 2006 - 1 of 2',
#  'dyfi gin distillery with still and barrel',
#  '10pcs 10mm charms crystal glass cube spacer beads craft loose bead findings',
#  'abstract painting by leonardo da vinci, steampunk, renascentist, art nouveau, style concept art, sharp focus, surreal colorful concept art, realism, photo, octane render, wide angle shot, epic cinematic shot of a dark, monochrome, glass negative, silver gelatine realistic, supersharp, supersharp, realistic, photographic',
#  'kodak portra 4 0 0, flashlight, muted colours, 1 9 2 0 s style, long shot, vivid photo of a room with concrete walls and a large large square square picture frame, tiny gaussian blur, haze, depth of field, 1 9 6 0 s metal furniture',
#  'patrick swayze a life in pictures: the outsiders 30th anniversary retrospective',
#  'estate lot of 3 hallmark white church & red & green houses christmas tre',
#  'hyperrealism photography computer simulation visualisation of the burning steampunk city block scale architectural model of george costanza playing games on their first day of the adriatic sea from the incal',
#  'zombie clowns from outer space',
#  'the grand canyon is one of the most spectacular places on earth, the sunset over the rocks just proves that.',
#  'lemonade-e-liquid',
#  'laughing guy at the sun pierce the heavens and is being hanged at the sun, from scene from a new york street, christmas presents, inside abandoned space station, by alena aenami artworks in 4 k photorealistic portrait, bright studio setting, studio lighting, chroma green background by denis villeneuve style volumetric ambient light',
#  'z scale - micro-trains - 994 01 250 - passenger car, lightweight, pullman - northern pacific - 4-pack',
#  'astronaut anime young girl with vibrant red hair, hourglass slim figure, jinx face, jinx expression, blue eyes, dungeons and dragons portrait, lovely smile, highly detailed, digital painting, artstation, concept art, sharp focus, illustration, art by artgerm and greg rutkowski and alphonse mucha',
#  'jeep unveils six moab easter safari concepts',
#  'how to make a paper boat',
#  'pretty little girl stock photography',
#  'our favorite cars (and not-cars) at the quail, a motorsports gathering - slide 2',
#  'mamidikaaya pappu or the raw mango curry is a speciality from andhra pradesh. the sour ,spicy curry is served with steamed rice and ghee and some fryums.',
#  'a realistic painting of abandoned urbex control room architecture unfinished building factory building city urbex by richard diebenkorn, nightvision neon noir uv light liberty city biopunk tokyo, archdaily, wallpaper, highly detailed, digital painting, trending on artstation octane render ',
#  'a fluffy baby lop eared bunny rabbit who sits on a circle in the park, cinematic camera shot, ultra detailed, octane render, unreal engine 5, raytracing, 8k,',
#  "[e3 2015] tom clancy's the division arriverà l'8 marzo",
#  'return to the left, looking at one & only the dead headband one size',
#  "yamagata bucket list: 15 best things to do in yamagata prefecture - japan's land of snow monsters",
#  'peanut-butter-honey-ice-cream--640x908.jpg',
#  'cofffee maker, ground coffee, and whole coffee beans',
#  '253 best hawaiian quilts images on pinterest | hawaiian quilts ... : hawaiian quilt pillows - adamdwight.com',
#  'zombie boy, whose real name is well-known for the garden stake outdoor plant outdoor nature mount scenery wilderness river and flaming mouth and sharp crystals sticking out in los angeles with open floor house plans farmhouse lake house living',
#  'jeans-how-to-pack-clothes-for-moving.jpg',
#  'portrait of ian karmel ',
#  'adult medieval costumes',
#  'monarch butterfly stained glass',
#  'russian traditional feature ethnic style',
#  'usa beer cap map cherry - glossy wood bottle cap holder - skyline workshop - made in the usa! - great christmas gift!',
#  "boho style: you don't have to be 20-something to be cool, mama! 3 hip items you'll love!",
#  'baby whale baby shower beverage table baby shower ideas pinterest',
#  'how to easily make french toast',
#  'outstanding photos by indian travel photographer aman chotani',
#  'new fashion spring summer wreath izmirmasajfo',
#  'colourful farm iced cupcakes',
#  'crochet baby sweater hat booties set heather grey 3-6 mo | pinterest ...',
#  'camp h photo collage 2.jpg',
#  'these 4-ingredient chewy pumpkin spice cookies are made with box cake mix; only 4 ingredients. topped with cream cheese frosting.  beautifuleatsandthings.com',
#  'simplicity, colorful iridescent metal, and fast black and white, close up, concept art, ',
#  'person laughing',
#  'ruched tulle off-the-shoulder sweetheart floor length tulle a-line prom dress featuring beaded embellished belt',
#  '1girl back_bow birthday blush bow braid buttons collar commentary dated english_text food_print food_themed_hair_ornament frilled_collar frilled_skirt frilled_sleeves frills gloves hair_bow hair_ornament hair_ribbon hat heart heart_hair_ornament highres layered_skirt looking_at_viewer love_live! love_live!_nijigasaki_high_school_idol_club macaron_hat open_mouth outstretched_arm pink_headwear puffy_short_sleeves puffy_sleeves ranemu red_bow red_skirt redhead ribbon short_hair short_sleeves side_braid signature simple_background single_braid skirt smile solo strawberry_hair_ornament strawberry_print uehara_ayumu upper_teeth white_background white_bow white_gloves white_skirt yellow_eyes yellow_ribbon',
#  'gluten-free vegan blueberry pancakes | yupitsvegan.com. light and fluffy vegan pancakes made with heart-healthy flax and oat flour.',
#  'digital painting of a future earth in the style of lee gibbons ',
#  "pulled pork burger | courtesy of chivuo's",
#  'landromantik wellnesshotel oswald bayerischer wald ger urlaub in 2019 pinterest. black bedroom furniture sets. home design ideas',
#  'pink mary janes with red cherries felt baby shoes can be',
#  '1920x1358 koe no katachi computer desktop backgrounds (sailor kingsman. find this pin  and more on a silent voice ...',
#  "ravensthorpe, wa australia 2016. 'six stages of banksia baxteri' (side 2) commissioned by form wa and cbh -  click for more about this project",
#  'a pink corset dating back to 1880s america.',
#  'mobius franzetta herzog william s burroughs, full of humaoid facehugger, in dark armor wielding a sword that flashes with lightning, aurora lighting. clouds and sky, northen lights, fantasy, realistic, minerals, vfx, ue4, root, green theme, camera view, ultra wide angle lens dark lighting',
#  'mt. baker lodging - cabine n ° 21',
#  'jogger by the cherry blossoms',
#  '{quilled} wedding cake',
#  'parvati maxi + dupatta - purple edition *desktop arcade* with retropie',
#  "les-pieces-cultes-d-yves-saint-laurent-10-things-you-didn't-did-not-know-about-ysl-yves-saint-laurent-mondrian-dress-dresses",
#  'le st geran one&only anniversary luxury mauritius 3',
#  '8 reasons to consider a winter wedding',
# ...
#  'north american black skin and beautiful fashion model shoot, masterpiece, sharp focus, illustration, art by artgerm and greg rutkowski and alphonse mucha and beeple global illumination ray tracing global illumination, radiant light, intricate environment',
#  '02-molecule-tiny-homes-architecture-with-a-tiny-home-1904-style-www-designstack-co',
#  'ireland, landscape, seascape, sunrise, antrim, northern ireland',
#  'klaus steiner wipes the windshield of his delorean as the delorean world tour caravan prepares to depart from the president abraham lincoln springfield – a doubletree by hilton hotel friday, april 1, 2016. the three european delorean owners have been touring the world in their cars, starting in austria in may 2015 and traveling through nepal, india, thailand, australia and other countries on their way to the united states. the tour will end in belfast, ireland in time for the 35th birthday of the delorean. the springfield stop was part of a promotion for the delorean convention and show 2016, scheduled in springfield in late july. ted schurter/the state journal-register',
#  'inpost invests £100 million to have 10,000 parcel lockers operational in the uk by 2023',
#  'detailed ancient roman empire timeline timeline description: the wallpaper above is winter cool for cool youth bedroom set, 1930s 1940s 30s 40s teal and orange pumpkin',
#  'lovely pair of tents!',
#  'a highly detailed portrait of frida kalho painted by gustave courbet',
#  '2003 ferretti custom flybridge for sale',
#  'why i changed my mind about bears ears',
#  'mint and gold baby bedding',
#  '"storm kids - 100w 12"" electric balance bike - green"',
#  "mother's day chocolate covered oreos",
#  'paris street corner - horse & cab, pedestrians, 1877 etching book illustration',
#  'a beautiful day in steamboat springs',
#  'the tudors - season 4 episode still',
#  'a photograph of the reception area of heaven, wide angle, epic cinematography, beautiful lighting, interior design, corporate photography, 24mm, fujifilm',
#  'boiled eggs with burlap placemat topped with delicious milk chocolate. for a unique resort in alps, switzerland on the natural spa to get married.',
#  'villain wearing a red oni mask, orange space suit, dark background, unreal engine 5, ultra realistic, detailed, fog, volumetric lighting, by greg rutkowski,',
#  'minimalist winter architecture by atey ghailan ( ( and edward hopper ) ) ',
#  'a 35mm photo of a fast futuristic! space ship!! flying through a nebulae filled with cyberpunk space stations!, concept art, matte painting, contrasting color scheme,',
#  'woodysclassicgrill_cobbsalad.jpg',
#  'vaporwave city, stylized as pixel art ',
#  'the dead rise from their graves and float to heaven, some assisted by angels. in the upper right, a couple is pulled to heaven on rosary beads, and just below that a risen body is caught in violent tug of war (detail), michelangelo, last judgment, sistine chapel, altar wall, fresco, 1534-1541 (vatican city, rome) fresco, 1534-1541 (vatican city, rome)',
#  'beautiful arizona backyard landscaping backyard',
#  'color portrait of elijah wood in the shire, dark, cinematic lighting, hyper realistic, sony 5 0 mm, photograph, kodachrome, film grain',
#  'baby christmas tree topper',
#  'cardi b as a belly dancer, full body, gypsy, sexy, beautiful, sultry, highly detailed, vivid colors, 8 k ',
#  'shed diy outdoor junk garden shed 7x7 gardening for garden shed in hampton nh discover browse thousands of other home design ideas for 2020 on backyard decorating ideas coffee',
#  'how to kill fire ants work in dirt stock photo #5978181',
#  'the summer workshop for 7 and 9 july , a lovely 3d hydrangea wall hanging',
#  'portrait of a solo knight rising from a slice of metal and blue jean shorts wearing a ripped mantle, robe. perfect face, fine details portrait, bokeh. anime masterpiece by haruto hoshi and yang inside an hourglass. the slugs are the weapons showroom, anime fantasy illustration by gaston bussiere, felicien rops, eugene grasset, janis rozentals ',
#  'is this a great way to have been relocated from other worlds ',
#  'madison cabin 120 exterior in fall',
#  'invery beat river dee 21',
#  'dubteriors t2 bay window interior in vw neptune blue with for bay window interior',
#  'happy birthday sushi cake sushi cake 2 by jumarco11',
#  'five kids hiking through grassy field with engaged counselor in telluride with a view of lone cone.',
#  '319 mizner lake estates drive',
#  'a man walking through the wasteland, post-apocalypse, cinematic',
#  'spring summer 2012',
#  'the annunciation of the secret map room by edward weston',
#  'high quality wooden garage doors any size made to measure for 10 foot high garage door',
#  'person holding white and neon demon, david hockney, 1972 acrylic on canvas, digital painting, trending on artstation',
#  'small garden yard decoration and refrence junglespirit gallery',
#  '100531 download wallpaper animals, tiger, snow, stroll, predator screensavers and pictures for free',
#  'house design yellow - 30 room colors for a vibrant home paint colors for bright interior design',
#  'brilliant birthday cake delivery in livonia, michigan wedding photography',
#  "saturday's mouse: challah french toast",
#  'juice box cartoon juice boxes with fruits and',
#  'antique herend tea cups.',
#  'early export porcelain covered jar - ruby',
#  'portrait of a mysterious cyberpunk man draped in a bodysuit, focus, realistic photo of donald trump hot dog suit.',
#  'forest cabins wallpaper background 26470 1538x851',
#  'chinese american culture | the official guide to portland',
#  "presidents welcome - e-packet - jeanne d'arc.jpg - wikimedia commons",
#  'still photo of coorg by riya jaiswal',
#  'a painting of three women picnicking in a small boat.',
#  "pope francis says death penalty 'inadmissible'",
#  'an old wizard with seaweed for hairs and beard, wearing fluent multicolored robes in an underwater alchemical laboratory. digital illustration. fantasy. detailed. waterbubbles. by artgerm, wlop, james jean, andrei riabovitchev, marc simonetti, yoshitaka amano',
#  'an oil painting by frazetta and marco bucci and loish and rossdraws and sam yang and samdoesarts and artgerm and tom',
#  '! dream cockpit view',
#  'slow war, trenches, exhausted, dirt, night, cigarette',
#  'cupcake papers and picks',
#  'the boy is playing the guitar, 8k, high resolution image from a tomb in a stream in the foreground, white background,symmetric, smooth shading, ultra detailed, rule of thirds fibonacci, intricate, cel shaded,',
#  'bride and groom showered in confetti on wedding day at lochgreen house hotel, ayrshire',
#  '2454 rachel-go ( large metallic picture brim special occasion hat with stylish double bow )',
#  'this mehndi green outfit totally pulled off our classic bridal wear with an unmatchable grace giving major bridal goals. featuring beautiful handwork, the blouse has a delicate arrangement of hand embellished floral patterns with zardozi work and finished with dangling balls. refined craftsmanship is at its best with hand embellished jaal, geometric patterns and floral bunches at the lehenga. this outfit is paired with an organza dupatta chann and finishing all around the edges making it a statement piece.',
#  '80 fabulous easter decorations you can make yourself - 80 fabulous easter decorations you can make yourself',
#  'sweet strawberry pinny - handmade girls dress',
#  'colorful painting sad look poster featuring the photograph the wooden woman',
#  '460108404 floral vine high wedge flip flops with crystal accents 5  98923.1431550521.jpg c 2',
#  'castle wedding cake pictures',
#  "abha shah (c) choreographer of surtaal performing arts, and her group members participate in a 'garba' dance rehearsal ahead of the forthcoming 'navratri' festival on the outskirts of ahmedabad, india.",
#  'a drawing of a steel worker, by dean cornwall ',
#  'foods that lower your libido | a bowl of sugar cubes',
#  'beautiful desert by ivan slosar',
#  'pretty garden wedding editorial with lilac and lavender',
#  'henri marius camille bouvet figurative painting - tea for two at the discoteque ',
#  'open foyer designs : amazing open foyer with beautiful stair case and balcony',
#  'top 10 fastest cars in the world 2017',
#  "danny wallace explains why captain marvel big game is easy to make a tilt shift photography, extreme close - up, illustration, highly detailed, artstation, by gustave dore', rendered in octane, trending on artstation ",
#  'cedar log cabin on the golden circle in iceland',
#  'still image of a woman sitting on a large cute anime m200 gaming',
#  'the holy cross.',
#  'sunset over st ives, cornwall',
#  'tilion 20cm soft unicorn heart plush toy baby kids appease rainbow sleeping pillow doll animal stuffed toy birthday gifts for girls',
#  'beautiful open rolling mountainscape, in the style of françois boucher, oil painting, trending on artstation',
#  '4822 meadow lane west vail, co 81657',
#  'this confetti pasta salad with lemon dijon dressing is the perfect side dish for summer entertaining!',
#  'blondies in a stack.',
#  'napoleon painting - napoleon bonaparte receiving queen louisa of prussia by nicolas louis francois gosse',
#  'black and gold crown in a ponytail, vintage hipster glasses, highly detailed, digital painting, wlop ',
#  'ryele daybed with cushions fabric: peridot',
#  'chaos by geert goiris, by tarkovsky, award - winning, concept art ',
#  "beautiful painting of 3 siamese cats by jacques nam, famous for his paintings of cats. oil on panel (plywood). art deco. 1930's dimensions: without frame: 46cmx33cm; with frame : 61.5cmx48.5cm.",
#  'spongebob dressed in a spider man costume',
#  '10 delicious festive chocolates with the aesthetics of akira, wearing cyberpunk goggles sitting on moon, wide angle, cinecolor, natural lighting, path traced, high coherence, realistic, high details, cinematic, 8k',
#  'portrait of nick jonas, wearing glasses, straight medium length hair, photorealistic, cinematic, scary lighting, atmospheric, cinematic, moody, in the style of victo ngai, kilian eng vibrant colors, cel shading, vivid colors 5 1 as a sumo wrestler portrait | big fat goblins, red castle on hill, post apocalyptic, dark',
#  '100% hand painted trinket box with handpainted peg doll',
#  'cookie tree and carousel from the beach club marketplace',
#  'light blue denim bucket hat',
#  'knight wearing armor made of thorns and glass rides a white unicorn into a forest clearing, digital illustration, radiant evening light, by greg rutkowski',
#  '188 best corner lot landscaping ideas images on pinterest ...',
#  'download free hd 2010 mercedes benz sls amg desert gold 2 wide wallpaper, image',
#  'character design, concept art, volumetric lightning, moorlands behind him, inventor facial expression, aesthetic octane render, cgsociety',
#  'pair of chinese famille rose millefleurs porcelain vase table lamps for sale 9',
#  'optimal league of legends artstation',
#  "elena found an amazing little garden walkway to place shane's daughter. i loved the light here!",
#  'mortal kombat 11: all the characters confirmed so far',
#  'cliff, beach and rainbow over the ocean in the catlins.',
#  'bullfinch on a branch of mountain ash. abstract hand drawn with soft pastel illustration royalty free illustration',
#  'lake tipsoo with mt. rainier  by james duffin',
#  'joysail valentine wreaths for front door red heart wreath for valentines day decorations outdoor indoor 16 inch artificial heart shaped wreath/for party wall decor',
#  'the lion king jon favreau',
#  'rear view, robe à la francaise, 1740-1760. cream silk, beautifully hand-painted with floral ornament pink flowers blue and gold and silver bouquet wedding paper',
#  'a landscape of a single tree with bushes nearby, studio ghibli, castle in the sky, animated, anime, illustrated, vibrant, by toei animation, by miyazaki, on artstation ',
#  'beautiful giant marijuana bud covered in stunning large moist trichomes trichomes trichomes as a silo in a field',
#  'cute gazelle family looking at camera hd wallpaper | hd nature ...',
#  '2000x1487 valentine heart with rose petals for just married flower floral barrettes - gift in a dark souls iii boss, highly detailed by adam adamowicz; 4k, 8k',
#  'gandhi memorial center library',
#  'tequila sunrise stock photography',
#  'priest blessing young girl on a pink bike',
#  'man with a tattooed back sitting on a box',
#  'decopac disney princess castle cake kit decorations topper',
#  'gorgeous red satin long sleeve formal prom gown by cutedress on',
#  'landscape round beach towel featuring the photograph the kelpies no.3 by phill thornton',
#  'tree deciduous pine , tree png clipart.',
#  'michael mcintyre as a shark and a short green fuzzy anthropomorphic male black anthro tiger in a 7-ft tall upside-down surreal elaborate open 18th century russian orthodox icon depicting child christ playing a wizard hat, hardware, books, cottagecore, extremely detailed, hyperreal, high details, unreal engine, raytraced, rtx, reflections ',
#  'noxious chain retire toothpaste lonely receptive complete and varied brushstrokes, splashes of neon, sacred geometry, esoteric art by artgerm and greg rutkowski, alphonse mucha, greg rutkowski, craig mullins jc leyendecker and greg rutkowski and alphonse mucha ',
#  'aetherpunk iron giant chainmail armor holding a shield and sword, centered, inking, etching, screen print, masterpiece, trending on artstation',
#  'tv headed man, ominous, wide angle, warm tones, beige colors, sunlight, digital 2 d game art',
#  '"dc\'s legends of tomorrow --""the chicago way""-- lgn208a_0307.jpg -- pictured (l-r): neal mcdonough as damien darhk, john barrowman as malcolm merlyn and matthew letscher as eobard thawne -- photo: jack rowand/the cw -- © 2016 the cw network, llc. all rights reserved"',
#  'neon tesseract hypercube floating in the background at night, cyberpunk art by the colorful ocean, kamakura scenery, the feeling of grimdark, sharp focus, non blurry, sharp, smooth',
#  'gold palm tree- art by linda woods poster',
#  ...]

# %%
prompt_dataframe.memory_usage(deep=True)

# %%
prompt_dataframe["text_tokens"] = None
prompt_dataframe["img_features"] = None

prompt_dataframe["text_tokens"] = prompt_dataframe["text_tokens"].astype(object)
prompt_dataframe["img_features"] = prompt_dataframe["img_features"].astype(object)

# %%
step_size = 100
finished_cnt = 0
finished_per_save = 25000

def load_img_for_row(path, width, height):
    sdutils.load_img(path)
    img = sdutils.load_img(path)
    if img.size == (width, height):
        img = img.crop([0, 0, width, height])
    
    return vit14_clip_preprocess(img)
    
def get_img_features(imgs_paths, widths, heights):
    preprocessed_imgs = tuple((load_img_for_row(img, width, height) for img, width, height in zip(imgs_paths, widths, heights)))
    preprocessed_imgs = torch.stack(preprocessed_imgs).cuda()
    encoded_imgs = vit14_clip_model.encode_image(preprocessed_imgs).float()
    return (encoded_imgs / encoded_imgs.norm(dim=-1, keepdim=True)).cpu().numpy().tolist()

def get_text_tokens(prompts):
    return clip.tokenize(prompts, truncate=True).cpu().numpy().tolist()

start_time = time.perf_counter()
prompts = prompt_dataframe["prompt"]
img_paths = prompt_dataframe["img_path"]
widths = prompt_dataframe["width"]
heights = prompt_dataframe["height"]

tokens = []
img_features = []

with torch.no_grad():
    for start in range(0, len(prompt_dataframe), step_size):
        tokens += get_text_tokens(prompts[start:start+step_size])
        img_features += get_img_features(img_paths[start:start+step_size],
                                         widths[start:start+step_size],
                                         heights[start:start+step_size])
        break
    
    

end = time.perf_counter()
per_datum = (end - start_time)/step_size
print(f"Time per datum: {per_datum}")
print(f"Rem time: {per_datum * (len(prompt_dataframe) - idx)/60} minutes")

# %%
prompt_dataframe.dtypes

# %%
from util import ReTerm
import re
def arg_prompt_split(command):
    args_iters = ReTerm.sd_args_regex.finditer(command)
    
    args = [command[it.start():it.end()].strip() for it in args_iters]
    prompt = re.sub('|'.join(args), "", command).strip()

    command_mapper = {
        '-width': "-W",
        "-height": "-H",
        "-cfg": "-C",
        "-cfg_scale": "-C",
        "-seed": "-S",
        "-steps": "-s",
        "-sampler": "-A",
        "-prior": "-p",
        "-ascii": "-a",
        "-separate-images": "-i",
        "-grid": "-g",
        "-number": "-n",
        "-tokenize": "-t"
    }
    no_value = {"-a", "-t", "-i", "-g", "-t", "-p"}
    
    recognized_args = command_mapper.keys() | command_mapper.values()

    def split_key_val(arg):
        split = [part.strip() for part in re.split('[ =]', arg.strip())]
        split[0] = re.sub(" +", " ", split[0])
        split[0] = re.sub("–", "-", split[0])
        split[0] = re.sub("--", "-", split[0]).strip()
        
        without_nums = re.sub(r"\d+", "", split[0])
        if without_nums in recognized_args and without_nums != split[0]:
            nums = re.findall(r"\d+", split[0])
            split.append(nums[0])
            split[0] = without_nums
            
        if split[0].lower() in command_mapper:
            split[0] = command_mapper[split[0].lower()]

        if len(split) != 2:
            return split[0], ""

        return split[0], split[1]

    key_val_pairs = [split_key_val(arg) for arg in args]
    args_to_remove = set()
    for idx, arg_pair in enumerate(key_val_pairs):
        key, val = arg_pair
        
        if key not in recognized_args or (not val and key not in no_value):
            # Add the origional arg to the prompt. This is a common typo
            # which affects the tokens
            prompt += f" {args[idx]}"
            args_to_remove.add(idx)
        
    key_val_pairs = [pair for idx, pair in enumerate(key_val_pairs) if idx not in args_to_remove]

    args = {entry[0]: entry[1] for entry in key_val_pairs if len(entry) == 2}
    return prompt.lower(), args

def fix_row_args(prompt_dataframe, idx, split_prompt, args):
    before_prompt = prompt_dataframe.loc[idx, "prompt"]
    #print(f"{idx} Before: {before_prompt[-15:]}")
    prompt_dataframe.at[idx, "prompt"] = split_prompt.strip()
    prompt_dataframe.at[idx, "text_tokens"] = clip.tokenize(split_prompt, truncate=True)[0].numpy().astype(np.uint16)
    seed = 0
    #print(args)
    """
    if "-S" in args:
        seed = args["-S"]
        prompt_dataframe.at[idx, "seed"] = int(seed)
    
    if "-s" in args:
        steps = args["-s"]
        prompt_dataframe.at[idx, "seed"] = int(steps)

    cfg = 7.0
    if "-C" in args:
        cfg = args["-C"]
        cfg = re.findall("\d+\.?\d*", cfg)[0]
        prompt_dataframe.at[idx, "cfg"] = float(cfg)
        
        
    sampler = "k_lms"
    if "-A" in args:
        sampler = args["-A"]
        prompt_dataframe.at[idx, "sampler"] = sampler
        
    num_imgs = 1
    if "-n" in args:
        num_imgs = args["-n"]
        prompt_dataframe.at[idx, "num_imgs"] = int(num_imgs)
        
    width = 512
    if "-W" in args:
        width = args["-W"]
        prompt_dataframe.at[idx, "width"] = width
        if width != 512:
            prompt_dataframe.at[idx, "img_features"] = None
        
    height = 512
    if "-H" in args:
        height = args["-H"]
        prompt_dataframe.at[idx, "height"] = height
        if height != 512:
            prompt_dataframe.at[idx, "img_features"] = None
    """
        
    #print(f"{idx} After: {prompt_dataframe.iloc[idx]}\n")


fix_cnt = 0
cut_cnt = 0
to_remove = []
for row in prompt_dataframe.itertuples(True):
    idx = row[0]

    if idx != 0 and idx % 100000 == 0:
        print(f"Fixed {fix_cnt} at idx {idx}")
        print(f"Cut {cut_cnt} at idx {idx}")
        
    prompt = row.prompt

    """
    cut_idx = re.search(r"[` ]*(\*\*WARNING\*\*|The seeds for each individual image are)", row.prompt) 
    if cut_idx:
        cut_idx = cut_idx.span()[0]
        cut_cnt += 1
        
        prompt = prompt[:cut_idx]
        print(prompt_dataframe.at[idx, "prompt"])
        prompt_dataframe.at[idx, "prompt"] = prompt
        print(prompt_dataframe.at[idx, "prompt"])
        prompt_dataframe.at[idx, "text_tokens"] = clip.tokenize(prompt, truncate=True)[0].numpy().astype(np.uint16)  
    """
    split_prompt, args = arg_prompt_split(prompt)

    if split_prompt != prompt.strip():
        fix_cnt += 1
        fix_row_args(prompt_dataframe, idx, split_prompt, args)
        
                       
    if row.text_tokens is None:
        prompt_dataframe.at[idx, "text_tokens"] = clip.tokenize(split_prompt, truncate=True)[0].numpy().astype(np.uint16)  
        
print("Cut fixes",cut_cnt) 
print(fix_cnt)
print(len(to_remove))
# Out:
# Fixed 105 at idx 100000
# Cut 0 at idx 100000
# Fixed 257 at idx 200000
# Cut 0 at idx 200000
# Fixed 357 at idx 300000
# Cut 0 at idx 300000
# Fixed 468 at idx 400000
# Cut 0 at idx 400000
# Fixed 567 at idx 500000
# Cut 0 at idx 500000
# Fixed 679 at idx 600000
# Cut 0 at idx 600000
# Fixed 794 at idx 700000
# Cut 0 at idx 700000
# Fixed 895 at idx 800000
# Cut 0 at idx 800000
# Fixed 1000 at idx 900000
# Cut 0 at idx 900000
# Fixed 1096 at idx 1000000
# Cut 0 at idx 1000000
# Fixed 1205 at idx 1100000
# Cut 0 at idx 1100000
# Fixed 1310 at idx 1200000
# Cut 0 at idx 1200000
# Fixed 1421 at idx 1300000
# Cut 0 at idx 1300000
# Fixed 1536 at idx 1400000
# Cut 0 at idx 1400000
# Fixed 1649 at idx 1500000
# Cut 0 at idx 1500000
# Fixed 1745 at idx 1600000
# Cut 0 at idx 1600000
# Fixed 1844 at idx 1700000
# Cut 0 at idx 1700000
# Fixed 1949 at idx 1800000
# Cut 0 at idx 1800000
# Fixed 2056 at idx 1900000
# Cut 0 at idx 1900000
# Fixed 2170 at idx 2000000
# Cut 0 at idx 2000000
# Fixed 2284 at idx 2100000
# Cut 0 at idx 2100000
# Fixed 2400 at idx 2200000
# Cut 0 at idx 2200000
# Fixed 2512 at idx 2300000
# Cut 0 at idx 2300000
# Fixed 2619 at idx 2400000
# Cut 0 at idx 2400000
# Fixed 2733 at idx 2500000
# Cut 0 at idx 2500000
# Fixed 2841 at idx 2600000
# Cut 0 at idx 2600000
# Fixed 2955 at idx 2700000
# Cut 0 at idx 2700000
# Fixed 3061 at idx 2800000
# Cut 0 at idx 2800000
# Fixed 3175 at idx 2900000
# Cut 0 at idx 2900000
# Fixed 3295 at idx 3000000
# Cut 0 at idx 3000000
# Fixed 3408 at idx 3100000
# Cut 0 at idx 3100000
# Fixed 3502 at idx 3200000
# Cut 0 at idx 3200000
# Fixed 3602 at idx 3300000
# Cut 0 at idx 3300000
# Fixed 3707 at idx 3400000
# Cut 0 at idx 3400000
# Fixed 3833 at idx 3500000
# Cut 0 at idx 3500000
# Fixed 3927 at idx 3600000
# Cut 0 at idx 3600000
# Fixed 4039 at idx 3700000
# Cut 0 at idx 3700000
# Fixed 4145 at idx 3800000
# Cut 0 at idx 3800000
# Fixed 4247 at idx 3900000
# Cut 0 at idx 3900000
# Fixed 4340 at idx 4000000
# Cut 0 at idx 4000000
# Fixed 4446 at idx 4100000
# Cut 0 at idx 4100000
# Fixed 4554 at idx 4200000
# Cut 0 at idx 4200000
# Fixed 4668 at idx 4300000
# Cut 0 at idx 4300000
# Fixed 4781 at idx 4400000
# Cut 0 at idx 4400000
# Fixed 4883 at idx 4500000
# Cut 0 at idx 4500000
# Fixed 4988 at idx 4600000
# Cut 0 at idx 4600000
# Fixed 5096 at idx 4700000
# Cut 0 at idx 4700000
# Fixed 5206 at idx 4800000
# Cut 0 at idx 4800000
# Fixed 5333 at idx 4900000
# Cut 0 at idx 4900000
# Fixed 5447 at idx 5000000
# Cut 0 at idx 5000000
# Fixed 5551 at idx 5100000
# Cut 0 at idx 5100000
# Fixed 5655 at idx 5200000
# Cut 0 at idx 5200000
# Fixed 5763 at idx 5300000
# Cut 0 at idx 5300000
# Fixed 5867 at idx 5400000
# Cut 0 at idx 5400000
# Fixed 5967 at idx 5500000
# Cut 0 at idx 5500000
# Fixed 6084 at idx 5600000
# Cut 0 at idx 5600000
# Fixed 6193 at idx 5700000
# Cut 0 at idx 5700000
# Fixed 6294 at idx 5800000
# Cut 0 at idx 5800000
# Fixed 6407 at idx 5900000
# Cut 0 at idx 5900000
# Fixed 6524 at idx 6000000
# Cut 0 at idx 6000000
# Fixed 6629 at idx 6100000
# Cut 0 at idx 6100000
# Fixed 6718 at idx 6200000
# Cut 0 at idx 6200000
# Fixed 6815 at idx 6300000
# Cut 0 at idx 6300000
# Fixed 6919 at idx 6400000
# Cut 0 at idx 6400000
# Fixed 7036 at idx 6500000
# Cut 0 at idx 6500000
# Fixed 7129 at idx 6600000
# Cut 0 at idx 6600000
# Fixed 7234 at idx 6700000
# Cut 0 at idx 6700000
# Fixed 7322 at idx 6800000
# Cut 0 at idx 6800000
# Fixed 7418 at idx 6900000
# Cut 0 at idx 6900000
# Fixed 7518 at idx 7000000
# Cut 0 at idx 7000000
# Fixed 7623 at idx 7100000
# Cut 0 at idx 7100000
# Fixed 7731 at idx 7200000
# Cut 0 at idx 7200000
# Fixed 7846 at idx 7300000
# Cut 0 at idx 7300000
# Fixed 7945 at idx 7400000
# Cut 0 at idx 7400000
# Fixed 8050 at idx 7500000
# Cut 0 at idx 7500000
# Fixed 8150 at idx 7600000
# Cut 0 at idx 7600000
# Fixed 8285 at idx 7700000
# Cut 0 at idx 7700000
# Fixed 8382 at idx 7800000
# Cut 0 at idx 7800000
# Fixed 8479 at idx 7900000
# Cut 0 at idx 7900000
# Fixed 8579 at idx 8000000
# Cut 0 at idx 8000000
# Fixed 8665 at idx 8100000
# Cut 0 at idx 8100000
# Fixed 8778 at idx 8200000
# Cut 0 at idx 8200000
# Fixed 8864 at idx 8300000
# Cut 0 at idx 8300000
# Fixed 8976 at idx 8400000
# Cut 0 at idx 8400000
# Fixed 9086 at idx 8500000
# Cut 0 at idx 8500000
# Fixed 9193 at idx 8600000
# Cut 0 at idx 8600000
# Fixed 9293 at idx 8700000
# Cut 0 at idx 8700000
# Fixed 9389 at idx 8800000
# Cut 0 at idx 8800000
# Fixed 9485 at idx 8900000
# Cut 0 at idx 8900000
# Fixed 9601 at idx 9000000
# Cut 0 at idx 9000000
# Fixed 9697 at idx 9100000
# Cut 0 at idx 9100000
# Fixed 9825 at idx 9200000
# Cut 0 at idx 9200000
# Fixed 9930 at idx 9300000
# Cut 0 at idx 9300000
# Fixed 10039 at idx 9400000
# Cut 0 at idx 9400000
# Fixed 10152 at idx 9500000
# Cut 0 at idx 9500000
# Fixed 10259 at idx 9600000
# Cut 0 at idx 9600000
# Fixed 10366 at idx 9700000
# Cut 0 at idx 9700000
# Fixed 10468 at idx 9800000
# Cut 0 at idx 9800000
# Fixed 10574 at idx 9900000
# Cut 0 at idx 9900000
# Fixed 10666 at idx 10000000
# Cut 0 at idx 10000000
# Fixed 10768 at idx 10100000
# Cut 0 at idx 10100000
# Fixed 10878 at idx 10200000
# Cut 0 at idx 10200000
# Fixed 10985 at idx 10300000
# Cut 0 at idx 10300000
# Fixed 11074 at idx 10400000
# Cut 0 at idx 10400000
# Fixed 11173 at idx 10500000
# Cut 0 at idx 10500000
# Fixed 11291 at idx 10600000
# Cut 0 at idx 10600000
# Fixed 11395 at idx 10700000
# Cut 0 at idx 10700000
# Fixed 11503 at idx 10800000
# Cut 0 at idx 10800000
# Fixed 11610 at idx 10900000
# Cut 0 at idx 10900000
# Fixed 11723 at idx 11000000
# Cut 0 at idx 11000000
# Fixed 11826 at idx 11100000
# Cut 0 at idx 11100000
# Fixed 11925 at idx 11200000
# Cut 0 at idx 11200000
# Fixed 12047 at idx 11300000
# Cut 0 at idx 11300000
# Fixed 12160 at idx 11400000
# Cut 0 at idx 11400000
# Fixed 12267 at idx 11500000
# Cut 0 at idx 11500000
# Fixed 12370 at idx 11600000
# Cut 0 at idx 11600000
# Fixed 12485 at idx 11700000
# Cut 0 at idx 11700000
# Fixed 12601 at idx 11800000
# Cut 0 at idx 11800000
# Fixed 12712 at idx 11900000
# Cut 0 at idx 11900000
# Fixed 12816 at idx 12000000
# Cut 0 at idx 12000000
# Fixed 12933 at idx 12100000
# Cut 0 at idx 12100000
# Fixed 13033 at idx 12200000
# Cut 0 at idx 12200000
# Fixed 13150 at idx 12300000
# Cut 0 at idx 12300000
# Fixed 13244 at idx 12400000
# Cut 0 at idx 12400000
# Fixed 13351 at idx 12500000
# Cut 0 at idx 12500000
# Fixed 13464 at idx 12600000
# Cut 0 at idx 12600000
# Fixed 13569 at idx 12700000
# Cut 0 at idx 12700000
# Fixed 13686 at idx 12800000
# Cut 0 at idx 12800000
# Fixed 13792 at idx 12900000
# Cut 0 at idx 12900000
# Fixed 13914 at idx 13000000
# Cut 0 at idx 13000000
# Fixed 14022 at idx 13100000
# Cut 0 at idx 13100000
# Fixed 14128 at idx 13200000
# Cut 0 at idx 13200000
# Fixed 14237 at idx 13300000
# Cut 0 at idx 13300000
# Fixed 14368 at idx 13400000
# Cut 0 at idx 13400000
# Fixed 14492 at idx 13500000
# Cut 0 at idx 13500000
# Fixed 14584 at idx 13600000
# Cut 0 at idx 13600000
# Fixed 14677 at idx 13700000
# Cut 0 at idx 13700000
# Fixed 14771 at idx 13800000
# Cut 0 at idx 13800000
# Fixed 14888 at idx 13900000
# Cut 0 at idx 13900000
# Fixed 14984 at idx 14000000
# Cut 0 at idx 14000000
# Fixed 15097 at idx 14100000
# Cut 0 at idx 14100000
# Fixed 15209 at idx 14200000
# Cut 0 at idx 14200000
# Fixed 15315 at idx 14300000
# Cut 0 at idx 14300000
# Fixed 15428 at idx 14400000
# Cut 0 at idx 14400000
# Fixed 15537 at idx 14500000
# Cut 0 at idx 14500000
# Fixed 15640 at idx 14600000
# Cut 0 at idx 14600000
# Fixed 15732 at idx 14700000
# Cut 0 at idx 14700000
# Fixed 15835 at idx 14800000
# Cut 0 at idx 14800000
# Fixed 15944 at idx 14900000
# Cut 0 at idx 14900000
# Fixed 16046 at idx 15000000
# Cut 0 at idx 15000000
# Fixed 16138 at idx 15100000
# Cut 0 at idx 15100000
# Fixed 16234 at idx 15200000
# Cut 0 at idx 15200000
# Fixed 16320 at idx 15300000
# Cut 0 at idx 15300000
# Fixed 16432 at idx 15400000
# Cut 0 at idx 15400000
# Fixed 16533 at idx 15500000
# Cut 0 at idx 15500000
# Fixed 16648 at idx 15600000
# Cut 0 at idx 15600000
# Fixed 16750 at idx 15700000
# Cut 0 at idx 15700000
# Fixed 16843 at idx 15800000
# Cut 0 at idx 15800000
# Fixed 16952 at idx 15900000
# Cut 0 at idx 15900000
# Fixed 17048 at idx 16000000
# Cut 0 at idx 16000000
# Fixed 17146 at idx 16100000
# Cut 0 at idx 16100000
# Fixed 17260 at idx 16200000
# Cut 0 at idx 16200000
# Fixed 17356 at idx 16300000
# Cut 0 at idx 16300000
# Fixed 17456 at idx 16400000
# Cut 0 at idx 16400000
# Fixed 17537 at idx 16500000
# Cut 0 at idx 16500000
# Fixed 17639 at idx 16600000
# Cut 0 at idx 16600000
# Fixed 17746 at idx 16700000
# Cut 0 at idx 16700000
# Cut fixes 0
# 17857
# 0

# %%
def calc_jaccard_similarity(text_a, text_b):
    doc1_tokens=set(text_a.lower().split())
    doc2_tokens=set(text_b.lower().split())
    div_inter = len(doc1_tokens.union(doc2_tokens))
    if div_inter == 0:
        return 0
    return len(doc1_tokens.intersection(doc2_tokens))/div_inter

prompt_dataframe.sort_values('prompt',inplace=True, ascending=False)
prompt_dataframe.reset_index(drop=True, inplace=True)

last_text = ""
threshold = 0.80
to_remove = []
next_remove_candidates = []
max_similar = 2
for cnt, row in enumerate(prompt_dataframe.itertuples(True)):
    if cnt % 100000 == 0:
        print(f"Removed {len(to_remove)} at cnt {cnt}")

    if len(row.prompt) == 0:
        print(row.prompt)
        to_remove.append(row[0])
    jaccard_similarity = calc_jaccard_similarity(last_text, row.prompt)
    if jaccard_similarity > threshold:
        next_remove_candidates.append((f"{row.prompt}", row[0]))
    else:
        next_remove_candidates.sort(key=lambda x: len(x))
        next_remove_candidates = [x[1] for x in next_remove_candidates]
        if len(next_remove_candidates) > max_similar:
            to_remove += next_remove_candidates[:-(max_similar)]
        next_remove_candidates = []
        last_text = row.prompt
        
print(len(to_remove))
# Out:
# Removed 0 at cnt 0
# Removed 4 at cnt 100000
# Removed 4 at cnt 200000
# Removed 4 at cnt 300000
# Removed 6 at cnt 400000
# Removed 6 at cnt 500000
# Removed 6 at cnt 600000
# Removed 6 at cnt 700000
# Removed 6 at cnt 800000
# Removed 6 at cnt 900000
# Removed 8 at cnt 1000000
# Removed 11 at cnt 1100000
# Removed 11 at cnt 1200000
# Removed 11 at cnt 1300000
# Removed 13 at cnt 1400000
# Removed 13 at cnt 1500000
# Removed 14 at cnt 1600000
# Removed 16 at cnt 1700000
# Removed 17 at cnt 1800000
# Removed 17 at cnt 1900000
# Removed 19 at cnt 2000000
# Removed 20 at cnt 2100000
# Removed 23 at cnt 2200000
# Removed 27 at cnt 2300000
# Removed 27 at cnt 2400000
# Removed 28 at cnt 2500000
# Removed 32 at cnt 2600000
# Removed 32 at cnt 2700000
# Removed 32 at cnt 2800000
# Removed 32 at cnt 2900000
# Removed 32 at cnt 3000000
# Removed 32 at cnt 3100000
# Removed 32 at cnt 3200000
# Removed 33 at cnt 3300000
# Removed 34 at cnt 3400000
# Removed 38 at cnt 3500000
# Removed 38 at cnt 3600000
# Removed 39 at cnt 3700000
# Removed 40 at cnt 3800000
# Removed 41 at cnt 3900000
# Removed 41 at cnt 4000000
# Removed 44 at cnt 4100000
# Removed 44 at cnt 4200000
# Removed 44 at cnt 4300000
# Removed 44 at cnt 4400000
# Removed 46 at cnt 4500000
# Removed 46 at cnt 4600000
# Removed 46 at cnt 4700000
# Removed 46 at cnt 4800000
# Removed 47 at cnt 4900000
# Removed 48 at cnt 5000000
# Removed 49 at cnt 5100000
# Removed 50 at cnt 5200000
# Removed 50 at cnt 5300000
# Removed 51 at cnt 5400000
# Removed 51 at cnt 5500000
# Removed 55 at cnt 5600000
# Removed 56 at cnt 5700000
# Removed 57 at cnt 5800000
# Removed 60 at cnt 5900000
# Removed 61 at cnt 6000000
# Removed 61 at cnt 6100000
# Removed 62 at cnt 6200000
# Removed 64 at cnt 6300000
# Removed 66 at cnt 6400000
# Removed 66 at cnt 6500000
# Removed 66 at cnt 6600000
# Removed 66 at cnt 6700000
# Removed 66 at cnt 6800000
# Removed 66 at cnt 6900000
# Removed 66 at cnt 7000000
# Removed 67 at cnt 7100000
# Removed 67 at cnt 7200000
# Removed 68 at cnt 7300000
# Removed 68 at cnt 7400000
# Removed 68 at cnt 7500000
# Removed 68 at cnt 7600000
# Removed 69 at cnt 7700000
# Removed 69 at cnt 7800000
# Removed 69 at cnt 7900000
# Removed 72 at cnt 8000000
# Removed 74 at cnt 8100000
# Removed 74 at cnt 8200000
# Removed 76 at cnt 8300000
# Removed 76 at cnt 8400000
# Removed 77 at cnt 8500000
# Removed 77 at cnt 8600000
# Removed 78 at cnt 8700000
# Removed 78 at cnt 8800000
# Removed 78 at cnt 8900000
# Removed 80 at cnt 9000000
# Removed 80 at cnt 9100000
# Removed 80 at cnt 9200000
# Removed 80 at cnt 9300000
# Removed 82 at cnt 9400000
# Removed 82 at cnt 9500000
# Removed 86 at cnt 9600000
# Removed 87 at cnt 9700000
# Removed 87 at cnt 9800000
# Removed 90 at cnt 9900000
# Removed 90 at cnt 10000000
# Removed 90 at cnt 10100000
# Removed 90 at cnt 10200000
# Removed 91 at cnt 10300000
# Removed 91 at cnt 10400000
# Removed 95 at cnt 10500000
# Removed 97 at cnt 10600000
# Removed 99 at cnt 10700000
# Removed 103 at cnt 10800000
# Removed 104 at cnt 10900000
# Removed 109 at cnt 11000000
# Removed 110 at cnt 11100000
# Removed 112 at cnt 11200000
# Removed 112 at cnt 11300000
# Removed 113 at cnt 11400000
# Removed 114 at cnt 11500000
# Removed 117 at cnt 11600000
# Removed 119 at cnt 11700000
# Removed 125 at cnt 11800000
# Removed 125 at cnt 11900000
# Removed 126 at cnt 12000000
# Removed 128 at cnt 12100000
# Removed 130 at cnt 12200000
# Removed 130 at cnt 12300000
# Removed 131 at cnt 12400000
# Removed 132 at cnt 12500000
# Removed 136 at cnt 12600000
# Removed 138 at cnt 12700000
# Removed 140 at cnt 12800000
# Removed 140 at cnt 12900000
# Removed 140 at cnt 13000000
# Removed 140 at cnt 13100000
# Removed 141 at cnt 13200000
# Removed 142 at cnt 13300000
# Removed 143 at cnt 13400000
# Removed 143 at cnt 13500000
# Removed 144 at cnt 13600000
# Removed 146 at cnt 13700000
# Removed 151 at cnt 13800000
# Removed 151 at cnt 13900000
# Removed 154 at cnt 14000000
# Removed 154 at cnt 14100000
# Removed 157 at cnt 14200000
# Removed 157 at cnt 14300000
# Removed 158 at cnt 14400000
# Removed 160 at cnt 14500000
# Removed 163 at cnt 14600000
# Removed 163 at cnt 14700000
# Removed 163 at cnt 14800000
# Removed 163 at cnt 14900000
# Removed 163 at cnt 15000000
# Removed 164 at cnt 15100000
# Removed 166 at cnt 15200000
# Removed 166 at cnt 15300000
# Removed 166 at cnt 15400000
# Removed 166 at cnt 15500000
# Removed 167 at cnt 15600000
# Removed 168 at cnt 15700000
# Removed 179 at cnt 15800000
# Removed 181 at cnt 15900000
# Removed 183 at cnt 16000000
# Removed 183 at cnt 16100000
# Removed 195 at cnt 16200000
# Removed 196 at cnt 16300000
# Removed 200 at cnt 16400000
# Removed 200 at cnt 16500000
# Removed 200 at cnt 16600000
# Removed 201 at cnt 16700000
# 201

# %%
for remove_idx in to_remove[:100]:
    print(prompt_dataframe.at[remove_idx, "prompt"])

# %%
print(len(to_remove))

# %%
print(len(prompt_dataframe))
prompt_dataframe.drop(prompt_dataframe.index[to_remove], inplace=True)
print(len(prompt_dataframe))
del to_remove
# Out:
# 16798395
# 16798194

# %%
# %timeit os.path.exists("/home/ubuntu/Main/sd_discord/preprocessed_imgs/0.png")

# %%
def load_img_for_row(img_path, width, height):
    img = sdutils.load_img(img_path)
    if img.size != (width, height):
        img = img.crop([0, 0, width, height])
    
    return img
    
def preprocess_img(preprocessor, img_path, width, height):
    return preprocessor(load_img_for_row(img_path, width, height))

preprocessed = preprocess_img(vit14_clip_preprocess, prompt_dataframe.at[0, "img_path"], prompt_dataframe.at[0, "width"], prompt_dataframe.at[0, "height"])

# %%
print(preprocessed.shape)

# %%
def load_img_for_row(row):
    img = sdutils.load_img(row.img_path)
    if img.size != (row.width, row.height):
        img = img.crop([0, 0, row.width, row.height])
    
    return img
    
def get_img_features(rows):
    imgs = [load_img_for_row(row) for row in rows]
    return [clip_model.encode_image_features(img)[0].cpu().numpy().tolist() for img in imgs]

idxs = []
text = []
imgs = []
per_process = 10000

finished_cnt = 0
finished_per_save = 20000
with torch.no_grad():
    start = time.perf_counter()
    for idx, row in enumerate(prompt_dataframe.itertuples()):
        idxs.append(idx)
        text.append(row.prompt)
        imgs.append(load_img_for_row(row))

        if len(idxs) > per_process:
            batch_tokens = clip.tokenize(text, truncate=True).cpu().numpy().tolist()
            img_features = [clip_model.encode_image_features(img)[0].cpu().numpy().tolist() for img in imgs]

            idxs = []
            text = []
            imgs = []
            for row_idx, text_tokens, img_feature in zip(idxs, batch_tokens, img_features):
                prompt_dataframe.at[row_idx, 'text_tokens'] = text_tokens
                prompt_dataframe.at[row_idx, 'img_features'] = img_feature
            finished_cnt += len(idxs)
            if finished_cnt > finished_per_save:
                prompt_dataframe.to_csv(df_file_path)
                finished_cnt = 0
                
            
            end = time.perf_counter()
            per_datum = (end - start)/per_process
            print(f"Time per datum: {per_datum}")
            print(f"Rem time: {per_datum * (len(prompt_dataframe) - idx)/60} minutes")
            start = time.perf_counter()
for row_idx, text_tokens, img_feature in zip(idxs, batch_tokens, img_features):
    prompt_dataframe.at[row_idx, 'text_tokens'] = text_tokens
    prompt_dataframe.at[row_idx, 'img_features'] = img_feature
    
finished_cnt += len(idxs)
if finished_cnt > finished_per_save:
    prompt_dataframe.to_csv(df_file_path)
    finished_cnt = 0

# %%
print(prompt_dataframe.loc[0, 'text_tokens'])
print(prompt_dataframe.loc[0, 'img_features'])

# %%
def process_elem(x, target_type):
    if type(x) != str:
        return x
    split_list = x.strip('[]').split(', ')
    return [target_type(x) for x in split_list]

prompt_dataframe['text_tokens'] = [process_elem(x, int) for x in prompt_dataframe['text_tokens']]
prompt_dataframe['urls'] = [process_elem(x, str) for x in prompt_dataframe['urls']]
prompt_dataframe['img_features'] = [process_elem(x, float) for x in prompt_dataframe['img_features']]
